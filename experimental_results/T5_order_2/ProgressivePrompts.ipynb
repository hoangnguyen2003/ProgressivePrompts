# %%
mv /kaggle/input/progressive-prompts/ProgressivePrompts /kaggle/working/
# Out:
# mv: cannot remove '/kaggle/input/progressive-prompts/ProgressivePrompts/environment.yaml': Read-only file system
# mv: cannot remove '/kaggle/input/progressive-prompts/ProgressivePrompts/LICENSE': Read-only file system
# mv: cannot remove '/kaggle/input/progressive-prompts/ProgressivePrompts/datasets/README.md': Read-only file system
# mv: cannot remove '/kaggle/input/progressive-prompts/ProgressivePrompts/datasets/src/data/ag/readme.txt': Read-only file system
# mv: cannot remove '/kaggle/input/progressive-prompts/ProgressivePrompts/datasets/src/data/ag/classes.txt': Read-only file system
# mv: cannot remove '/kaggle/input/progressive-prompts/ProgressivePrompts/datasets/src/data/ag/train.csv': Read-only file system
# mv: cannot remove '/kaggle/input/progressive-prompts/ProgressivePrompts/datasets/src/data/ag/test.csv': Read-only file system
# mv: cannot remove '/kaggle/input/progressive-prompts/ProgressivePrompts/datasets/src/data/dbpedia/readme.txt': Read-only file system
# ...

# %%
# %cd /kaggle/working/ProgressivePrompts/T5_codebase
import os
os.mkdir("load_checkpoint")
# %mv /kaggle/input/t5-order-2/current_checkpoint.pt /kaggle/working/ProgressivePrompts/T5_codebase/load_checkpoint
# Out:
# /kaggle/working/ProgressivePrompts/T5_codebase
# mv: cannot remove '/kaggle/input/t5-order-2/current_checkpoint.pt': Read-only file system

# %%
# %cd /kaggle/working/ProgressivePrompts
# %conda env create -f environment.yaml
# Out:
# /kaggle/working/ProgressivePrompts
# Retrieving notices: ...working... done
# ...
# WARNING conda.models.version:get_matcher(556): Using .* with relational operator is superfluous and deprecated and will be removed in a future version of conda. Your spec was 1.6.0.*, but conda is ignoring the .* and treating it as 1.6.0
# WARNING conda.models.version:get_matcher(556): Using .* with relational operator is superfluous and deprecated and will be removed in a future version of conda. Your spec was 1.7.1.*, but conda is ignoring the .* and treating it as 1.7.1
# WARNING conda.models.version:get_matcher(556): Using .* with relational operator is superfluous and deprecated and will be removed in a future version of conda. Your spec was 1.9.0.*, but conda is ignoring the .* and treating it as 1.9.0
# done
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 23.7.4
#   latest version: 23.10.0
#
# Please update conda by running
#
# ...

# %%
# %cd T5_codebase
import os
os.mkdir("results")
os.mkdir("save_checkpoint")
# Out:
# /kaggle/working/ProgressivePrompts/T5_codebase

# %%
# !source activate nlp && python train_t5_cl.py --task_list dbpedia_14 amazon ag_news yahoo_answers_topics \
--lr 0.3 --num_epochs 10 --freeze_weights 1 --prefix_len 50 --batch_size 4 \
--model_name t5-large --early_stopping 1 \
--save_name T5_order_2 --save_dir results
# Out:
# Downloading: 100%|█████████████████████████| 1.18k/1.18k [00:00<00:00, 1.45MB/s]
# Downloading: 100%|█████████████████████████| 2.75G/2.75G [00:51<00:00, 57.0MB/s]
# Downloading: 100%|███████████████████████████| 773k/773k [00:00<00:00, 15.7MB/s]
# Freezing weights
# /opt/conda/envs/nlp/lib/python3.9/site-packages/transformers/optimization.py:306: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
# dbpedia_14
# ...
# Dataset dbpedia_14 downloaded and prepared to /root/.cache/huggingface/datasets/dbpedia_14/dbpedia_14/2.0.0/01dab9e10d969eadcdbc918be5a09c9190a24caeae33b10eee8f367a1e3f1f0c. Subsequent calls will reuse this data.
# ...

# %%
# !source activate nlp && python train_t5_cl.py --task_list dbpedia_14 amazon ag_news yahoo_answers_topics \
--lr 0.3 --num_epochs 10 --freeze_weights 1 --prefix_len 50 --batch_size 4 \
--model_name t5-large --early_stopping 1 \
--save_name T5_order_2 --save_dir results --continue_train 1
# Out:
# Downloading: 100%|██████████████████████████| 1.18k/1.18k [00:00<00:00, 966kB/s]
# Downloading: 100%|█████████████████████████| 2.75G/2.75G [00:52<00:00, 56.3MB/s]
# Downloading: 100%|███████████████████████████| 773k/773k [00:00<00:00, 2.39MB/s]
# Freezing weights
# /opt/conda/envs/nlp/lib/python3.9/site-packages/transformers/optimization.py:306: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
# dbpedia_14
# ...
# Dataset dbpedia_14 downloaded and prepared to /root/.cache/huggingface/datasets/dbpedia_14/dbpedia_14/2.0.0/01dab9e10d969eadcdbc918be5a09c9190a24caeae33b10eee8f367a1e3f1f0c. Subsequent calls will reuse this data.
# ...

# %%
# !source activate nlp && python train_t5_cl.py --task_list dbpedia_14 amazon ag_news yahoo_answers_topics \
--lr 0.3 --num_epochs 10 --freeze_weights 1 --prefix_len 50 --batch_size 4 \
--model_name t5-large --early_stopping 1 \
--save_name T5_order_2 --save_dir results --continue_train 1
# Out:
# Downloading: 100%|██████████████████████████| 1.18k/1.18k [00:00<00:00, 968kB/s]
# Downloading: 100%|█████████████████████████| 2.75G/2.75G [00:49<00:00, 59.2MB/s]
# Downloading: 100%|███████████████████████████| 773k/773k [00:00<00:00, 6.61MB/s]
# Freezing weights
# /opt/conda/envs/nlp/lib/python3.9/site-packages/transformers/optimization.py:306: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
# dbpedia_14
# ...
# Dataset dbpedia_14 downloaded and prepared to /root/.cache/huggingface/datasets/dbpedia_14/dbpedia_14/2.0.0/01dab9e10d969eadcdbc918be5a09c9190a24caeae33b10eee8f367a1e3f1f0c. Subsequent calls will reuse this data.
# ...

# %%
# !source activate nlp && python train_t5_cl.py --task_list dbpedia_14 amazon ag_news yahoo_answers_topics \
--lr 0.3 --num_epochs 10 --freeze_weights 1 --prefix_len 50 --batch_size 4 \
--model_name t5-large --early_stopping 1 \
--save_name T5_order_2 --save_dir results --continue_train 1
# Out:
# Downloading: 100%|█████████████████████████| 1.18k/1.18k [00:00<00:00, 1.45MB/s]
# Downloading: 100%|█████████████████████████| 2.75G/2.75G [01:59<00:00, 24.7MB/s]
# Downloading: 100%|███████████████████████████| 773k/773k [00:00<00:00, 12.2MB/s]
# Freezing weights
# /opt/conda/envs/nlp/lib/python3.9/site-packages/transformers/optimization.py:306: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
# dbpedia_14
# ...
# Dataset dbpedia_14 downloaded and prepared to /root/.cache/huggingface/datasets/dbpedia_14/dbpedia_14/2.0.0/01dab9e10d969eadcdbc918be5a09c9190a24caeae33b10eee8f367a1e3f1f0c. Subsequent calls will reuse this data.
# ...

# %%
# !source activate nlp && python train_t5_cl.py --task_list dbpedia_14 amazon ag_news yahoo_answers_topics \
--lr 0.3 --num_epochs 10 --freeze_weights 1 --prefix_len 50 --batch_size 4 \
--model_name t5-large --early_stopping 1 \
--save_name T5_order_2 --save_dir results --continue_train 1
# Out:
# Downloading: 100%|█████████████████████████| 1.18k/1.18k [00:00<00:00, 1.13MB/s]
# Downloading: 100%|█████████████████████████| 2.75G/2.75G [00:51<00:00, 56.9MB/s]
# Downloading: 100%|███████████████████████████| 773k/773k [00:00<00:00, 6.23MB/s]
# Freezing weights
# /opt/conda/envs/nlp/lib/python3.9/site-packages/transformers/optimization.py:306: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
# dbpedia_14
# ...
# Dataset dbpedia_14 downloaded and prepared to /root/.cache/huggingface/datasets/dbpedia_14/dbpedia_14/2.0.0/01dab9e10d969eadcdbc918be5a09c9190a24caeae33b10eee8f367a1e3f1f0c. Subsequent calls will reuse this data.
# ...

# %%
# !source activate nlp && python train_t5_cl.py --task_list dbpedia_14 amazon ag_news yahoo_answers_topics \
--lr 0.3 --num_epochs 10 --freeze_weights 1 --prefix_len 50 --batch_size 4 \
--model_name t5-large --early_stopping 1 \
--save_name T5_order_2 --save_dir results --continue_train 1
# Out:
# Downloading: 100%|██████████████████████████| 1.18k/1.18k [00:00<00:00, 914kB/s]
# Downloading: 100%|█████████████████████████| 2.75G/2.75G [00:50<00:00, 57.9MB/s]
# Downloading: 100%|███████████████████████████| 773k/773k [00:00<00:00, 4.25MB/s]
# Freezing weights
# /opt/conda/envs/nlp/lib/python3.9/site-packages/transformers/optimization.py:306: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
# dbpedia_14
# ...
# Dataset dbpedia_14 downloaded and prepared to /root/.cache/huggingface/datasets/dbpedia_14/dbpedia_14/2.0.0/01dab9e10d969eadcdbc918be5a09c9190a24caeae33b10eee8f367a1e3f1f0c. Subsequent calls will reuse this data.
# ...

# %%
# !source activate nlp && python train_t5_cl.py --task_list dbpedia_14 amazon ag_news yahoo_answers_topics \
--lr 0.3 --num_epochs 10 --freeze_weights 1 --prefix_len 50 --batch_size 4 \
--model_name t5-large --early_stopping 1 \
--save_name T5_order_2 --save_dir results --continue_train 1
# Out:
# Downloading: 100%|█████████████████████████| 1.18k/1.18k [00:00<00:00, 1.17MB/s]
# Downloading: 100%|█████████████████████████| 2.75G/2.75G [00:50<00:00, 58.9MB/s]
# Downloading: 100%|███████████████████████████| 773k/773k [00:00<00:00, 4.24MB/s]
# Freezing weights
# /opt/conda/envs/nlp/lib/python3.9/site-packages/transformers/optimization.py:306: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
# dbpedia_14
# ...
# Dataset dbpedia_14 downloaded and prepared to /root/.cache/huggingface/datasets/dbpedia_14/dbpedia_14/2.0.0/01dab9e10d969eadcdbc918be5a09c9190a24caeae33b10eee8f367a1e3f1f0c. Subsequent calls will reuse this data.
# ...

# %%
# %mv /kaggle/working/ProgressivePrompts/T5_codebase/save_checkpoint/current_checkpoint.pt /kaggle/working/
# %cd /kaggle/working
from IPython.display import FileLink
FileLink(r'current_checkpoint.pt')
# Out:
# /kaggle/working
# /kaggle/working/current_checkpoint.pt

# %%
import numpy as np
res = np.load('/kaggle/working/ProgressivePrompts/T5_codebase/results/T5_order_2/results_dict.npy', allow_pickle=True)

# %%
res
# Out:
# array({'test': {'dbpedia_14': 0.99, 'amazon': 0.644, 'ag_news': 0.928, 'yahoo_answers_topics': 0.7764}, 'dbpedia_14': [0.9868571428571429, 0.9885714285714285, 0.9902857142857143, 0.9897142857142858, 0.9885714285714285, 0.99, 0.9911428571428571, 0.9902857142857143, 0.9911428571428571, 0.9891428571428571], 'amazon': [0.5064, 0.5464, 0.5632, 0.5808, 0.6016, 0.596, 0.6, 0.6032, 0.6056, 0.6104], 'ag_news': [0.913, 0.914, 0.918, 0.917, 0.916, 0.923, 0.928, 0.927, 0.929, 0.928], 'yahoo_answers_topics': [0.7252, 0.7348, 0.75, 0.7536, 0.7596, 0.772, 0.7656, 0.7656, 0.7676, 0.7676]},
#       dtype=object)

# %%
# !source activate nlp && python train_t5_cl.py --task_list dbpedia_14 amazon ag_news yahoo_answers_topics \
--lr 0.3 --num_epochs 10 --freeze_weights 1 --prefix_len 50 --batch_size 4 \
--model_name t5-large --early_stopping 1 \
--save_name T5_order_2 --save_dir results --continue_train 1 --test_eval_after_every_task 1
# Out:
# Downloading: 100%|█████████████████████████| 1.18k/1.18k [00:00<00:00, 1.37MB/s]
# Downloading: 100%|█████████████████████████| 2.75G/2.75G [00:52<00:00, 56.7MB/s]
# Downloading: 100%|███████████████████████████| 773k/773k [00:00<00:00, 2.41MB/s]
# Freezing weights
# /opt/conda/envs/nlp/lib/python3.9/site-packages/transformers/optimization.py:306: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
# dbpedia_14
# ...
# Dataset dbpedia_14 downloaded and prepared to /root/.cache/huggingface/datasets/dbpedia_14/dbpedia_14/2.0.0/01dab9e10d969eadcdbc918be5a09c9190a24caeae33b10eee8f367a1e3f1f0c. Subsequent calls will reuse this data.
# ...

# %%
import numpy as np
res = np.load('/kaggle/working/ProgressivePrompts/T5_codebase/results/T5_order_2/results_dict.npy', allow_pickle=True)

# %%
res
# Out:
# array({'test': {'dbpedia_14': 0.99, 'amazon': 0.644, 'ag_news': 0.928, 3: {'dbpedia_14': 0.0, 'amazon': 0.0, 'ag_news': 0.474, 'yahoo_answers_topics': 0.7764}}, 'dbpedia_14': [0.9868571428571429, 0.9885714285714285, 0.9902857142857143, 0.9897142857142858, 0.9885714285714285, 0.99, 0.9911428571428571, 0.9902857142857143, 0.9911428571428571, 0.9891428571428571], 'amazon': [0.5064, 0.5464, 0.5632, 0.5808, 0.6016, 0.596, 0.6, 0.6032, 0.6056, 0.6104], 'ag_news': [0.913, 0.914, 0.918, 0.917, 0.916, 0.923, 0.928, 0.927, 0.929, 0.928], 'yahoo_answers_topics': [0.7252, 0.7348, 0.75, 0.7536, 0.7596, 0.772, 0.7656, 0.7656, 0.7676, 0.7668]},
#       dtype=object)
