# %%
mv /kaggle/input/large-number-tasks/ProgressivePrompts /kaggle/working/
# Out:
# mv: cannot remove '/kaggle/input/large-number-tasks/ProgressivePrompts/environment.yaml': Read-only file system
# mv: cannot remove '/kaggle/input/large-number-tasks/ProgressivePrompts/LICENSE': Read-only file system
# mv: cannot remove '/kaggle/input/large-number-tasks/ProgressivePrompts/datasets/README.md': Read-only file system
# mv: cannot remove '/kaggle/input/large-number-tasks/ProgressivePrompts/datasets/src/data/amazon/train.csv': Read-only file system
# mv: cannot remove '/kaggle/input/large-number-tasks/ProgressivePrompts/datasets/src/data/amazon/test.csv': Read-only file system
# mv: cannot remove '/kaggle/input/large-number-tasks/ProgressivePrompts/BERT_codebase/train_soft_prompt.py': Read-only file system
# mv: cannot remove '/kaggle/input/large-number-tasks/ProgressivePrompts/BERT_codebase/train_cl2.py': Read-only file system
# mv: cannot remove '/kaggle/input/large-number-tasks/ProgressivePrompts/BERT_codebase/run_prog_prompts.sh': Read-only file system
# ...

# %%
# %cd /kaggle/working/ProgressivePrompts/T5_codebase
import os
os.mkdir("load_checkpoint")
# %mv /kaggle/input/t5-20-2/current_checkpoint.pt /kaggle/working/ProgressivePrompts/T5_codebase/load_checkpoint
# Out:
# /kaggle/working/ProgressivePrompts/T5_codebase
# mv: cannot remove '/kaggle/input/t5-20-2/current_checkpoint.pt': Read-only file system

# %%
# %cd /kaggle/working/ProgressivePrompts
# %conda env create -f environment.yaml
# Out:
# /kaggle/working/ProgressivePrompts
# Retrieving notices: ...working... done
# ...
# WARNING conda.models.version:get_matcher(556): Using .* with relational operator is superfluous and deprecated and will be removed in a future version of conda. Your spec was 1.7.1.*, but conda is ignoring the .* and treating it as 1.7.1
# WARNING conda.models.version:get_matcher(556): Using .* with relational operator is superfluous and deprecated and will be removed in a future version of conda. Your spec was 1.8.0.*, but conda is ignoring the .* and treating it as 1.8.0
# WARNING conda.models.version:get_matcher(556): Using .* with relational operator is superfluous and deprecated and will be removed in a future version of conda. Your spec was 1.9.0.*, but conda is ignoring the .* and treating it as 1.9.0
# done
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 23.7.4
#   latest version: 23.10.0
#
# Please update conda by running
#
# ...

# %%
# %cd T5_codebase
import os
os.mkdir("results")
os.mkdir("save_checkpoint")
# Out:
# /kaggle/working/ProgressivePrompts/T5_codebase

# %%
# !source activate nlp && python train_t5_cl.py --task_list multirc boolq wic mnli cb copa qqp rte imdb sst2 dbpedia_14 ag_news yelp_review_full amazon yahoo_answers_topics \
--lr 0.3 --num_epochs 300 --freeze_weights 1 --prefix_len 10 --batch_size 4 \
--model_name t5-large --early_stopping 1 --select_k_per_class 20 \
--save_name large_T5_order_2 --save_dir results
# Out:
# Downloading: 100%|█████████████████████████| 1.18k/1.18k [00:00<00:00, 1.08MB/s]
# Downloading: 100%|█████████████████████████| 2.75G/2.75G [00:52<00:00, 56.4MB/s]
# Downloading: 100%|███████████████████████████| 773k/773k [00:00<00:00, 2.39MB/s]
# Freezing weights
# /opt/conda/envs/nlp/lib/python3.9/site-packages/transformers/optimization.py:306: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
# multirc
# ...
# Dataset super_glue downloaded and prepared to /root/.cache/huggingface/datasets/super_glue/multirc/1.0.2/d040c658e2ddef6934fdd97deb45c777b6ff50c524781ea434e7219b56a428a7. Subsequent calls will reuse this data.
# ...

# %%
# !source activate nlp && python train_t5_cl.py --task_list multirc boolq wic mnli cb copa qqp rte imdb sst2 dbpedia_14 ag_news yelp_review_full amazon yahoo_answers_topics \
--lr 0.3 --num_epochs 300 --freeze_weights 1 --prefix_len 10 --batch_size 4 \
--model_name t5-large --early_stopping 1 --select_k_per_class 20 \
--save_name large_T5_order_2 --save_dir results --continue_train 1
# Out:
# Downloading: 100%|█████████████████████████| 1.18k/1.18k [00:00<00:00, 1.11MB/s]
# Downloading: 100%|█████████████████████████| 2.75G/2.75G [00:53<00:00, 55.3MB/s]
# Downloading: 100%|███████████████████████████| 773k/773k [00:00<00:00, 2.51MB/s]
# Freezing weights
# /opt/conda/envs/nlp/lib/python3.9/site-packages/transformers/optimization.py:306: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
# multirc
# ...
# Dataset super_glue downloaded and prepared to /root/.cache/huggingface/datasets/super_glue/multirc/1.0.2/d040c658e2ddef6934fdd97deb45c777b6ff50c524781ea434e7219b56a428a7. Subsequent calls will reuse this data.
# ...

# %%
# !source activate nlp && python train_t5_cl.py --task_list multirc boolq wic mnli cb copa qqp rte imdb sst2 dbpedia_14 ag_news yelp_review_full amazon yahoo_answers_topics \
--lr 0.3 --num_epochs 300 --freeze_weights 1 --prefix_len 10 --batch_size 4 \
--model_name t5-large --early_stopping 1 --select_k_per_class 20 \
--save_name large_T5_order_2 --save_dir results --continue_train 1
# Out:
# Downloading: 100%|█████████████████████████| 1.18k/1.18k [00:00<00:00, 1.08MB/s]
# Downloading: 100%|█████████████████████████| 2.75G/2.75G [01:15<00:00, 38.9MB/s]
# Downloading: 100%|███████████████████████████| 773k/773k [00:00<00:00, 3.91MB/s]
# Freezing weights
# /opt/conda/envs/nlp/lib/python3.9/site-packages/transformers/optimization.py:306: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
# multirc
# ...
# Dataset super_glue downloaded and prepared to /root/.cache/huggingface/datasets/super_glue/multirc/1.0.2/d040c658e2ddef6934fdd97deb45c777b6ff50c524781ea434e7219b56a428a7. Subsequent calls will reuse this data.
# ...

# %%
# !source activate nlp && python train_t5_cl.py --task_list multirc boolq wic mnli cb copa qqp rte imdb sst2 dbpedia_14 ag_news yelp_review_full amazon yahoo_answers_topics \
--lr 0.3 --num_epochs 300 --freeze_weights 1 --prefix_len 10 --batch_size 4 \
--model_name t5-large --early_stopping 1 --select_k_per_class 20 \
--save_name large_T5_order_2 --save_dir results --continue_train 1
# Out:
# Downloading: 100%|█████████████████████████| 1.18k/1.18k [00:00<00:00, 1.17MB/s]
# Downloading: 100%|█████████████████████████| 2.75G/2.75G [00:52<00:00, 55.8MB/s]
# Downloading: 100%|███████████████████████████| 773k/773k [00:00<00:00, 8.80MB/s]
# Freezing weights
# /opt/conda/envs/nlp/lib/python3.9/site-packages/transformers/optimization.py:306: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
# multirc
# ...
# Dataset super_glue downloaded and prepared to /root/.cache/huggingface/datasets/super_glue/multirc/1.0.2/d040c658e2ddef6934fdd97deb45c777b6ff50c524781ea434e7219b56a428a7. Subsequent calls will reuse this data.
# ...

# %%
# !source activate nlp && python train_t5_cl.py --task_list multirc boolq wic mnli cb copa qqp rte imdb sst2 dbpedia_14 ag_news yelp_review_full amazon yahoo_answers_topics \
--lr 0.3 --num_epochs 300 --freeze_weights 1 --prefix_len 10 --batch_size 4 \
--model_name t5-large --early_stopping 1 --select_k_per_class 20 \
--save_name large_T5_order_2 --save_dir results --continue_train 1
# Out:
# Downloading: 100%|██████████████████████████| 1.18k/1.18k [00:00<00:00, 849kB/s]
# Downloading: 100%|█████████████████████████| 2.75G/2.75G [03:32<00:00, 13.9MB/s]
# Downloading: 100%|███████████████████████████| 773k/773k [00:00<00:00, 1.34MB/s]
# Freezing weights
# /opt/conda/envs/nlp/lib/python3.9/site-packages/transformers/optimization.py:306: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
# multirc
# ...
# Dataset super_glue downloaded and prepared to /root/.cache/huggingface/datasets/super_glue/multirc/1.0.2/d040c658e2ddef6934fdd97deb45c777b6ff50c524781ea434e7219b56a428a7. Subsequent calls will reuse this data.
# ...

# %%
# !source activate nlp && python train_t5_cl.py --task_list multirc boolq wic mnli cb copa qqp rte imdb sst2 dbpedia_14 ag_news yelp_review_full amazon yahoo_answers_topics \
--lr 0.3 --num_epochs 300 --freeze_weights 1 --prefix_len 10 --batch_size 4 \
--model_name t5-large --early_stopping 1 --select_k_per_class 20 \
--save_name large_T5_order_2 --save_dir results --continue_train 1
# Out:
# Downloading: 100%|██████████████████████████| 1.18k/1.18k [00:00<00:00, 932kB/s]
# Downloading: 100%|█████████████████████████| 2.75G/2.75G [00:52<00:00, 56.3MB/s]
# Downloading: 100%|███████████████████████████| 773k/773k [00:00<00:00, 11.0MB/s]
# Freezing weights
# /opt/conda/envs/nlp/lib/python3.9/site-packages/transformers/optimization.py:306: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
# multirc
# ...
# Dataset super_glue downloaded and prepared to /root/.cache/huggingface/datasets/super_glue/multirc/1.0.2/d040c658e2ddef6934fdd97deb45c777b6ff50c524781ea434e7219b56a428a7. Subsequent calls will reuse this data.
# ...

# %%
# !source activate nlp && python train_t5_cl.py --task_list multirc boolq wic mnli cb copa qqp rte imdb sst2 dbpedia_14 ag_news yelp_review_full amazon yahoo_answers_topics \
--lr 0.3 --num_epochs 300 --freeze_weights 1 --prefix_len 10 --batch_size 4 \
--model_name t5-large --early_stopping 1 --select_k_per_class 20 \
--save_name large_T5_order_2 --save_dir results --continue_train 1
# Out:
# Freezing weights
# /opt/conda/envs/nlp/lib/python3.9/site-packages/transformers/optimization.py:306: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
# multirc
# Reusing dataset super_glue (/root/.cache/huggingface/datasets/super_glue/multirc/1.0.2/d040c658e2ddef6934fdd97deb45c777b6ff50c524781ea434e7219b56a428a7)
# ...

# %%
# %mv /kaggle/working/ProgressivePrompts/T5_codebase/save_checkpoint/current_checkpoint.pt /kaggle/working/
# %cd /kaggle/working
from IPython.display import FileLink
FileLink(r'current_checkpoint.pt')
# Out:
# /kaggle/working
# /kaggle/working/current_checkpoint.pt

# %%
import numpy as np
res = np.load('/kaggle/working/ProgressivePrompts/T5_codebase/results/large_T5_order_2/results_dict.npy', allow_pickle=True)

# %%
res
# Out:
# array({'test': {'multirc': 0.82, 'boolq': 0.806, 'wic': 0.6112852664576802, 'mnli': 0.86, 'cb': (0.9642857142857143, 0.9731615673644659), 'copa': 0.52, 'qqp': 0.896, 'rte': 0.8129496402877698, 'imdb': 0.934, 'sst2': 0.9275, 'dbpedia_14': 0.9765714285714285, 'ag_news': 0.847, 'yelp_review_full': 0.5808, 'amazon': 0.4864, 'yahoo_answers_topics': 0.6688}, 'multirc': [0.8399999999999999, 0.68, 0.7840000000000001, 0.8000000000000002, 0.83, 0.804, 0.836, 0.824, 0.842, 0.848, 0.844, 0.834, 0.836, 0.8399999999999999, 0.842, 0.836, 0.834, 0.83, 0.8399999999999999, 0.838, 0.838, 0.842, 0.838, 0.822, 0.826, 0.8140000000000001, 0.83, 0.818, 0.806, 0.802], 'boolq': [0.764, 0.784, 0.808, 0.808, 0.802, 0.79, 0.814, 0.792, 0.788, 0.786, 0.728, 0.66, 0.68, 0.704, 0.654, 0.672, 0.676, 0.618, 0.604, 0.594, 0.576, 0.572, 0.556, 0.564, 0.568, 0.536, 0.536, 0.542, 0.516, 0.51], 'wic': [0.5047021943573667, 0.5579937304075235, 0.64576802507837, 0.6081504702194357, 0.6426332288401254, 0.6833855799373041, 0.6
# ...
