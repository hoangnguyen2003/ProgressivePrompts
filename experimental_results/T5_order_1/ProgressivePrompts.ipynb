# %%
mv /kaggle/input/progressive-prompts/ProgressivePrompts /kaggle/working/
# Out:
# mv: cannot remove '/kaggle/input/progressive-prompts/ProgressivePrompts/environment.yaml': Read-only file system
# mv: cannot remove '/kaggle/input/progressive-prompts/ProgressivePrompts/LICENSE': Read-only file system
# mv: cannot remove '/kaggle/input/progressive-prompts/ProgressivePrompts/datasets/README.md': Read-only file system
# mv: cannot remove '/kaggle/input/progressive-prompts/ProgressivePrompts/datasets/src/data/ag/readme.txt': Read-only file system
# mv: cannot remove '/kaggle/input/progressive-prompts/ProgressivePrompts/datasets/src/data/ag/classes.txt': Read-only file system
# mv: cannot remove '/kaggle/input/progressive-prompts/ProgressivePrompts/datasets/src/data/ag/train.csv': Read-only file system
# mv: cannot remove '/kaggle/input/progressive-prompts/ProgressivePrompts/datasets/src/data/ag/test.csv': Read-only file system
# mv: cannot remove '/kaggle/input/progressive-prompts/ProgressivePrompts/datasets/src/data/dbpedia/readme.txt': Read-only file system
# ...

# %%
# %cd /kaggle/working/ProgressivePrompts/T5_codebase
import os
os.mkdir("load_checkpoint")
# %mv /kaggle/input/t5-order-1/current_checkpoint.pt /kaggle/working/ProgressivePrompts/T5_codebase/load_checkpoint
# Out:
# /kaggle/working/ProgressivePrompts/T5_codebase
# mv: cannot remove '/kaggle/input/t5-order-1/current_checkpoint.pt': Read-only file system

# %%
# %cd /kaggle/working/ProgressivePrompts
# %conda env create -f environment.yaml
# Out:
# /kaggle/working/ProgressivePrompts
# Retrieving notices: ...working... done
# ...
# WARNING conda.models.version:get_matcher(556): Using .* with relational operator is superfluous and deprecated and will be removed in a future version of conda. Your spec was 1.6.0.*, but conda is ignoring the .* and treating it as 1.6.0
# WARNING conda.models.version:get_matcher(556): Using .* with relational operator is superfluous and deprecated and will be removed in a future version of conda. Your spec was 1.8.0.*, but conda is ignoring the .* and treating it as 1.8.0
# WARNING conda.models.version:get_matcher(556): Using .* with relational operator is superfluous and deprecated and will be removed in a future version of conda. Your spec was 1.9.0.*, but conda is ignoring the .* and treating it as 1.9.0
# done
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 23.7.4
#   latest version: 23.10.0
#
# Please update conda by running
#
# ...

# %%
# %cd T5_codebase
import os
os.mkdir("results")
os.mkdir("save_checkpoint")
# Out:
# /kaggle/working/ProgressivePrompts/T5_codebase

# %%
# !source activate nlp && python train_t5_cl.py --task_list dbpedia_14 amazon yahoo_answers_topics ag_news \
--lr 0.3 --num_epochs 10 --freeze_weights 1 --prefix_len 50 --batch_size 4 \
--model_name t5-large --early_stopping 1 \
--save_name T5_order_1 --save_dir results
# Out:
# Downloading: 100%|█████████████████████████| 1.18k/1.18k [00:00<00:00, 1.02MB/s]
# Downloading: 100%|█████████████████████████| 2.75G/2.75G [00:51<00:00, 57.4MB/s]
# Downloading: 100%|███████████████████████████| 773k/773k [00:00<00:00, 13.8MB/s]
# Freezing weights
# /opt/conda/envs/nlp/lib/python3.9/site-packages/transformers/optimization.py:306: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
# dbpedia_14
# ...
# Dataset dbpedia_14 downloaded and prepared to /root/.cache/huggingface/datasets/dbpedia_14/dbpedia_14/2.0.0/01dab9e10d969eadcdbc918be5a09c9190a24caeae33b10eee8f367a1e3f1f0c. Subsequent calls will reuse this data.
# ...

# %%
# !source activate nlp && python train_t5_cl.py --task_list dbpedia_14 amazon yahoo_answers_topics ag_news \
--lr 0.3 --num_epochs 10 --freeze_weights 1 --prefix_len 50 --batch_size 4 \
--model_name t5-large --early_stopping 1 \
--save_name T5_order_1 --save_dir results --continue_train 1
# Out:
# Downloading: 100%|█████████████████████████| 1.18k/1.18k [00:00<00:00, 1.24MB/s]
# Downloading: 100%|█████████████████████████| 2.75G/2.75G [00:50<00:00, 58.3MB/s]
# Downloading: 100%|███████████████████████████| 773k/773k [00:00<00:00, 4.20MB/s]
# Freezing weights
# /opt/conda/envs/nlp/lib/python3.9/site-packages/transformers/optimization.py:306: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
# dbpedia_14
# ...
# Dataset dbpedia_14 downloaded and prepared to /root/.cache/huggingface/datasets/dbpedia_14/dbpedia_14/2.0.0/01dab9e10d969eadcdbc918be5a09c9190a24caeae33b10eee8f367a1e3f1f0c. Subsequent calls will reuse this data.
# ...

# %%
# !source activate nlp && python train_t5_cl.py --task_list dbpedia_14 amazon yahoo_answers_topics ag_news \
--lr 0.3 --num_epochs 10 --freeze_weights 1 --prefix_len 50 --batch_size 4 \
--model_name t5-large --early_stopping 1 \
--save_name T5_order_1 --save_dir results --continue_train 1
# Out:
# Downloading: 100%|█████████████████████████| 1.18k/1.18k [00:00<00:00, 1.06MB/s]
# Downloading: 100%|█████████████████████████| 2.75G/2.75G [00:51<00:00, 57.7MB/s]
# Downloading: 100%|███████████████████████████| 773k/773k [00:00<00:00, 16.2MB/s]
# Freezing weights
# /opt/conda/envs/nlp/lib/python3.9/site-packages/transformers/optimization.py:306: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
# dbpedia_14
# ...
# Dataset dbpedia_14 downloaded and prepared to /root/.cache/huggingface/datasets/dbpedia_14/dbpedia_14/2.0.0/01dab9e10d969eadcdbc918be5a09c9190a24caeae33b10eee8f367a1e3f1f0c. Subsequent calls will reuse this data.
# ...

# %%
# !source activate nlp && python train_t5_cl.py --task_list dbpedia_14 amazon yahoo_answers_topics ag_news \
--lr 0.3 --num_epochs 10 --freeze_weights 1 --prefix_len 50 --batch_size 4 \
--model_name t5-large --early_stopping 1 \
--save_name T5_order_1 --save_dir results --continue_train 1
# Out:
# Downloading: 100%|██████████████████████████| 1.18k/1.18k [00:00<00:00, 773kB/s]
# Downloading: 100%|█████████████████████████| 2.75G/2.75G [00:51<00:00, 57.8MB/s]
# Downloading: 100%|███████████████████████████| 773k/773k [00:00<00:00, 2.43MB/s]
# Freezing weights
# /opt/conda/envs/nlp/lib/python3.9/site-packages/transformers/optimization.py:306: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
# dbpedia_14
# ...
# Dataset dbpedia_14 downloaded and prepared to /root/.cache/huggingface/datasets/dbpedia_14/dbpedia_14/2.0.0/01dab9e10d969eadcdbc918be5a09c9190a24caeae33b10eee8f367a1e3f1f0c. Subsequent calls will reuse this data.
# ...

# %%
# !source activate nlp && python train_t5_cl.py --task_list dbpedia_14 amazon yahoo_answers_topics ag_news \
--lr 0.3 --num_epochs 10 --freeze_weights 1 --prefix_len 50 --batch_size 4 \
--model_name t5-large --early_stopping 1 \
--save_name T5_order_1 --save_dir results --continue_train 1
# Out:
# Downloading: 100%|█████████████████████████| 1.18k/1.18k [00:00<00:00, 1.03MB/s]
# Downloading: 100%|█████████████████████████| 2.75G/2.75G [00:51<00:00, 57.6MB/s]
# Downloading: 100%|███████████████████████████| 773k/773k [00:00<00:00, 3.15MB/s]
# Freezing weights
# /opt/conda/envs/nlp/lib/python3.9/site-packages/transformers/optimization.py:306: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
# dbpedia_14
# ...
# Dataset dbpedia_14 downloaded and prepared to /root/.cache/huggingface/datasets/dbpedia_14/dbpedia_14/2.0.0/01dab9e10d969eadcdbc918be5a09c9190a24caeae33b10eee8f367a1e3f1f0c. Subsequent calls will reuse this data.
# ...

# %%
# !source activate nlp && python train_t5_cl.py --task_list dbpedia_14 amazon yahoo_answers_topics ag_news \
--lr 0.3 --num_epochs 10 --freeze_weights 1 --prefix_len 50 --batch_size 4 \
--model_name t5-large --early_stopping 1 \
--save_name T5_order_1 --save_dir results --continue_train 1
# Out:
# Downloading: 100%|█████████████████████████| 1.18k/1.18k [00:00<00:00, 1.20MB/s]
# Downloading: 100%|█████████████████████████| 2.75G/2.75G [00:50<00:00, 58.1MB/s]
# Downloading: 100%|███████████████████████████| 773k/773k [00:00<00:00, 4.42MB/s]
# Freezing weights
# /opt/conda/envs/nlp/lib/python3.9/site-packages/transformers/optimization.py:306: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
# dbpedia_14
# ...
# Dataset dbpedia_14 downloaded and prepared to /root/.cache/huggingface/datasets/dbpedia_14/dbpedia_14/2.0.0/01dab9e10d969eadcdbc918be5a09c9190a24caeae33b10eee8f367a1e3f1f0c. Subsequent calls will reuse this data.
# ...

# %%
# !source activate nlp && python train_t5_cl.py --task_list dbpedia_14 amazon yahoo_answers_topics ag_news \
--lr 0.3 --num_epochs 10 --freeze_weights 1 --prefix_len 50 --batch_size 4 \
--model_name t5-large --early_stopping 1 \
--save_name T5_order_1 --save_dir results --continue_train 1
# Out:
# Downloading: 100%|█████████████████████████| 1.18k/1.18k [00:00<00:00, 1.26MB/s]
# Downloading: 100%|█████████████████████████| 2.75G/2.75G [00:50<00:00, 58.7MB/s]
# Downloading: 100%|███████████████████████████| 773k/773k [00:00<00:00, 17.2MB/s]
# Freezing weights
# /opt/conda/envs/nlp/lib/python3.9/site-packages/transformers/optimization.py:306: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
# dbpedia_14
# ...
# Dataset dbpedia_14 downloaded and prepared to /root/.cache/huggingface/datasets/dbpedia_14/dbpedia_14/2.0.0/01dab9e10d969eadcdbc918be5a09c9190a24caeae33b10eee8f367a1e3f1f0c. Subsequent calls will reuse this data.
# ...

# %%
# %mv /kaggle/working/ProgressivePrompts/T5_codebase/save_checkpoint/current_checkpoint.pt /kaggle/working/
# %cd /kaggle/working
from IPython.display import FileLink
FileLink(r'current_checkpoint.pt')
# Out:
# /kaggle/working
# /kaggle/working/current_checkpoint.pt

# %%
import numpy as np
res = np.load('/kaggle/working/ProgressivePrompts/T5_codebase/results/T5_order_1/results_dict.npy', allow_pickle=True)

# %%
res
# Out:
# array({'test': {'dbpedia_14': 0.9925714285714285, 'amazon': 0.6584, 'yahoo_answers_topics': 0.778, 'ag_news': 0.934}, 'dbpedia_14': [0.9845714285714285, 0.9888571428571429, 0.9891428571428571, 0.9905714285714285, 0.9914285714285714, 0.9914285714285714, 0.99, 0.988, 0.9902857142857143, 0.9894285714285714], 'amazon': [0.4832, 0.528, 0.5528, 0.5752, 0.5944, 0.592, 0.5968, 0.584, 0.592, 0.604], 'yahoo_answers_topics': [0.7404, 0.746, 0.7636, 0.76, 0.7644, 0.7664, 0.77, 0.7676, 0.7672, 0.7668], 'ag_news': [0.894, 0.901, 0.895, 0.904, 0.908, 0.919, 0.917, 0.92, 0.911, 0.919]},
#       dtype=object)

# %%
# !source activate nlp && python train_t5_cl.py --task_list dbpedia_14 amazon yahoo_answers_topics ag_news \
--lr 0.3 --num_epochs 10 --freeze_weights 1 --prefix_len 50 --batch_size 4 \
--model_name t5-large --early_stopping 1 \
--save_name T5_order_1 --save_dir results --continue_train 1 --test_eval_after_every_task 1
# Out:
# Downloading: 100%|█████████████████████████| 1.18k/1.18k [00:00<00:00, 1.01MB/s]
# Downloading: 100%|█████████████████████████| 2.75G/2.75G [00:51<00:00, 57.8MB/s]
# Downloading: 100%|███████████████████████████| 773k/773k [00:00<00:00, 2.37MB/s]
# Freezing weights
# /opt/conda/envs/nlp/lib/python3.9/site-packages/transformers/optimization.py:306: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
# dbpedia_14
# ...
# Dataset dbpedia_14 downloaded and prepared to /root/.cache/huggingface/datasets/dbpedia_14/dbpedia_14/2.0.0/01dab9e10d969eadcdbc918be5a09c9190a24caeae33b10eee8f367a1e3f1f0c. Subsequent calls will reuse this data.
# ...

# %%
import numpy as np
res = np.load('/kaggle/working/ProgressivePrompts/T5_codebase/results/T5_order_1/results_dict.npy', allow_pickle=True)

# %%
res
# Out:
# array({'test': {'dbpedia_14': 0.9925714285714285, 'amazon': 0.6584, 'yahoo_answers_topics': 0.778, 3: {'dbpedia_14': 0.0, 'amazon': 0.0, 'yahoo_answers_topics': 0.2464, 'ag_news': 0.931}}, 'dbpedia_14': [0.9845714285714285, 0.9888571428571429, 0.9891428571428571, 0.9905714285714285, 0.9914285714285714, 0.9914285714285714, 0.99, 0.988, 0.9902857142857143, 0.9894285714285714], 'amazon': [0.4832, 0.528, 0.5528, 0.5752, 0.5944, 0.592, 0.5968, 0.584, 0.592, 0.604], 'yahoo_answers_topics': [0.7404, 0.746, 0.7636, 0.76, 0.7644, 0.7664, 0.77, 0.7676, 0.7672, 0.7668], 'ag_news': [0.894, 0.901, 0.895, 0.904, 0.908, 0.919, 0.917, 0.92, 0.922, 0.92]},
#       dtype=object)
