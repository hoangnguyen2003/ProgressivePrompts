# %%
mv /kaggle/input/large-number-tasks/ProgressivePrompts /kaggle/working/
# Out:
# mv: cannot remove '/kaggle/input/large-number-tasks/ProgressivePrompts/environment.yaml': Read-only file system
# mv: cannot remove '/kaggle/input/large-number-tasks/ProgressivePrompts/LICENSE': Read-only file system
# mv: cannot remove '/kaggle/input/large-number-tasks/ProgressivePrompts/datasets/README.md': Read-only file system
# mv: cannot remove '/kaggle/input/large-number-tasks/ProgressivePrompts/datasets/src/data/amazon/train.csv': Read-only file system
# mv: cannot remove '/kaggle/input/large-number-tasks/ProgressivePrompts/datasets/src/data/amazon/test.csv': Read-only file system
# mv: cannot remove '/kaggle/input/large-number-tasks/ProgressivePrompts/BERT_codebase/train_soft_prompt.py': Read-only file system
# mv: cannot remove '/kaggle/input/large-number-tasks/ProgressivePrompts/BERT_codebase/train_cl2.py': Read-only file system
# mv: cannot remove '/kaggle/input/large-number-tasks/ProgressivePrompts/BERT_codebase/run_prog_prompts.sh': Read-only file system
# ...

# %%
# %cd /kaggle/working/ProgressivePrompts/BERT_codebase
import os
os.mkdir("load_checkpoint")
# %mv /kaggle/input/bert-1000-2/current_checkpoint.pt /kaggle/working/ProgressivePrompts/BERT_codebase/load_checkpoint
# Out:
# /kaggle/working/ProgressivePrompts/BERT_codebase
# mv: cannot remove '/kaggle/input/bert-1000-2/current_checkpoint.pt': Read-only file system

# %%
# %cd /kaggle/working/ProgressivePrompts
# %conda env create -f environment.yaml
# Out:
# /kaggle/working/ProgressivePrompts
# Retrieving notices: ...working... done
# ...
# WARNING conda.models.version:get_matcher(556): Using .* with relational operator is superfluous and deprecated and will be removed in a future version of conda. Your spec was 1.8.0.*, but conda is ignoring the .* and treating it as 1.8.0
# WARNING conda.models.version:get_matcher(556): Using .* with relational operator is superfluous and deprecated and will be removed in a future version of conda. Your spec was 1.9.0.*, but conda is ignoring the .* and treating it as 1.9.0
# WARNING conda.models.version:get_matcher(556): Using .* with relational operator is superfluous and deprecated and will be removed in a future version of conda. Your spec was 1.6.0.*, but conda is ignoring the .* and treating it as 1.6.0
# done
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 23.7.4
#   latest version: 23.10.0
#
# Please update conda by running
#
# ...

# %%
# %cd BERT_codebase
import os
os.mkdir("results")
os.mkdir("save_checkpoint")
# Out:
# /kaggle/working/ProgressivePrompts/BERT_codebase

# %%
# !source activate nlp && python train_cl2.py --task_list multirc boolq wic mnli cb copa qqp rte imdb sst2 dbpedia_14 ag_news yelp_review_full amazon yahoo_answers_topics \
--prefix_MLP residual_MLP2 --lr 1e-4 --num_epochs 40 --freeze_weights 1 --prefix_len 20 \
--early_stopping 1 --seq_len 180 --prompt_tuning 1 --select_k_per_class 1000 \
--save_name large_1000_BERT_order_2 --save_dir results
# Out:
# Max repeats =  0
# Using MLP reparametrization with bottleneck =  800
# Downloading: 100%|███████████████████████████| 28.0/28.0 [00:00<00:00, 26.8kB/s]
# Downloading: 100%|██████████████████████████████| 570/570 [00:00<00:00, 536kB/s]
# Downloading: 100%|███████████████████████████| 226k/226k [00:00<00:00, 26.8MB/s]
# Downloading: 100%|███████████████████████████| 455k/455k [00:00<00:00, 32.0MB/s]
# Downloading: 100%|███████████████████████████| 420M/420M [00:11<00:00, 37.7MB/s]
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertAdapterModel: ['cls.predictions.transform.LayerNorm.bias', 'cls.seq_relationship.bias', 'cls.predictions.transform.dense.weight', 'cls.predictions.decoder.weight', 'cls.seq_relationship.weight', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.bias', 'cls.predictions.transform.dense.bias']
# ...

# %%
# !source activate nlp && python train_cl2.py --task_list multirc boolq wic mnli cb copa qqp rte imdb sst2 dbpedia_14 ag_news yelp_review_full amazon yahoo_answers_topics \
--prefix_MLP residual_MLP2 --lr 1e-4 --num_epochs 40 --freeze_weights 1 --prefix_len 20 \
--early_stopping 1 --seq_len 180 --prompt_tuning 1 --select_k_per_class 1000 \
--save_name large_1000_BERT_order_2 --save_dir results --continue_train 1
# Out:
# Max repeats =  0
# Using MLP reparametrization with bottleneck =  800
# Downloading: 100%|███████████████████████████| 28.0/28.0 [00:00<00:00, 24.0kB/s]
# Downloading: 100%|██████████████████████████████| 570/570 [00:00<00:00, 679kB/s]
# Downloading: 100%|███████████████████████████| 226k/226k [00:00<00:00, 31.0MB/s]
# Downloading: 100%|███████████████████████████| 455k/455k [00:00<00:00, 26.6MB/s]
# Downloading: 100%|███████████████████████████| 420M/420M [00:11<00:00, 38.1MB/s]
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertAdapterModel: ['cls.predictions.bias', 'cls.predictions.decoder.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.seq_relationship.weight', 'cls.seq_relationship.bias', 'cls.predictions.transform.dense.bias', 'cls.predictions.transform.dense.weight']
# ...

# %%
# !source activate nlp && python train_cl2.py --task_list multirc boolq wic mnli cb copa qqp rte imdb sst2 dbpedia_14 ag_news yelp_review_full amazon yahoo_answers_topics \
--prefix_MLP residual_MLP2 --lr 1e-4 --num_epochs 40 --freeze_weights 1 --prefix_len 20 \
--early_stopping 1 --seq_len 180 --prompt_tuning 1 --select_k_per_class 1000 \
--save_name large_1000_BERT_order_2 --save_dir results --continue_train 1
# Out:
# Max repeats =  0
# Using MLP reparametrization with bottleneck =  800
# Downloading: 100%|███████████████████████████| 28.0/28.0 [00:00<00:00, 14.9kB/s]
# Downloading: 100%|██████████████████████████████| 570/570 [00:00<00:00, 582kB/s]
# Downloading: 100%|███████████████████████████| 226k/226k [00:00<00:00, 7.02MB/s]
# Downloading: 100%|███████████████████████████| 455k/455k [00:00<00:00, 3.74MB/s]
# Downloading: 100%|███████████████████████████| 420M/420M [00:07<00:00, 58.2MB/s]
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertAdapterModel: ['cls.predictions.decoder.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.transform.dense.bias', 'cls.seq_relationship.weight', 'cls.predictions.transform.dense.weight', 'cls.seq_relationship.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.bias']
# ...

# %%
# !source activate nlp && python train_cl2.py --task_list multirc boolq wic mnli cb copa qqp rte imdb sst2 dbpedia_14 ag_news yelp_review_full amazon yahoo_answers_topics \
--prefix_MLP residual_MLP2 --lr 1e-4 --num_epochs 40 --freeze_weights 1 --prefix_len 20 \
--early_stopping 1 --seq_len 180 --prompt_tuning 1 --select_k_per_class 1000 \
--save_name large_1000_BERT_order_2 --save_dir results --continue_train 1
# Out:
# Max repeats =  0
# Using MLP reparametrization with bottleneck =  800
# Downloading: 100%|███████████████████████████| 28.0/28.0 [00:00<00:00, 40.6kB/s]
# Downloading: 100%|██████████████████████████████| 570/570 [00:00<00:00, 809kB/s]
# Downloading: 100%|███████████████████████████| 226k/226k [00:00<00:00, 7.53MB/s]
# Downloading: 100%|███████████████████████████| 455k/455k [00:00<00:00, 9.82MB/s]
# Downloading: 100%|███████████████████████████| 420M/420M [00:07<00:00, 60.0MB/s]
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertAdapterModel: ['cls.predictions.transform.LayerNorm.bias', 'cls.predictions.transform.dense.weight', 'cls.predictions.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.seq_relationship.bias', 'cls.predictions.decoder.weight', 'cls.seq_relationship.weight', 'cls.predictions.transform.dense.bias']
# ...

# %%
# %mv /kaggle/working/ProgressivePrompts/BERT_codebase/save_checkpoint/current_checkpoint.pt /kaggle/working/
# %cd /kaggle/working
from IPython.display import FileLink
FileLink(r'current_checkpoint.pt')
# Out:
# /kaggle/working
# /kaggle/working/current_checkpoint.pt

# %%
import numpy as np
res = np.load('/kaggle/working/ProgressivePrompts/BERT_codebase/results/large_1000_BERT_order_2/results_dict.npy', allow_pickle=True)

# %%
res
# Out:
# array({0: {'multirc': [0.48333333333333334, 0.48333333333333334, 0.48333333333333334, 0.48333333333333334, 0.48333333333333334, 0.48333333333333334, 0.48333333333333334, 0.4866666666666667, 0.48, 0.5366666666666666, 0.48333333333333334, 0.55, 0.48333333333333334, 0.48, 0.5333333333333333, 0.5633333333333334, 0.56, 0.5533333333333333, 0.48333333333333334, 0.5333333333333333, 0.56, 0.54, 0.5466666666666666, 0.55, 0.54, 0.48333333333333334, 0.48333333333333334, 0.48333333333333334, 0.48333333333333334, 0.48333333333333334, 0.48333333333333334, 0.48333333333333334, 0.48333333333333334, 0.48333333333333334, 0.4866666666666667, 0.48, 0.5366666666666666, 0.5166666666666667, 0.54, 0.55], 'boolq': [], 'wic': [], 'mnli': [], 'cb': [], 'copa': [], 'qqp': [], 'rte': [], 'imdb': [], 'sst2': [], 'dbpedia_14': [], 'ag_news': [], 'yelp_review_full': [], 'amazon': [], 'yahoo_answers_topics': []}, 'test': {'multirc': [0.49], 'boolq': [0.5], 'wic': [0.5893416927899686], 'mnli': [0.6688888888888889], 'c
# ...
