# %%
mv /kaggle/input/large-number-tasks/ProgressivePrompts /kaggle/working/
# Out:
# mv: cannot remove '/kaggle/input/large-number-tasks/ProgressivePrompts/environment.yaml': Read-only file system
# mv: cannot remove '/kaggle/input/large-number-tasks/ProgressivePrompts/LICENSE': Read-only file system
# mv: cannot remove '/kaggle/input/large-number-tasks/ProgressivePrompts/datasets/README.md': Read-only file system
# mv: cannot remove '/kaggle/input/large-number-tasks/ProgressivePrompts/datasets/src/data/amazon/train.csv': Read-only file system
# mv: cannot remove '/kaggle/input/large-number-tasks/ProgressivePrompts/datasets/src/data/amazon/test.csv': Read-only file system
# mv: cannot remove '/kaggle/input/large-number-tasks/ProgressivePrompts/BERT_codebase/train_soft_prompt.py': Read-only file system
# mv: cannot remove '/kaggle/input/large-number-tasks/ProgressivePrompts/BERT_codebase/train_cl2.py': Read-only file system
# mv: cannot remove '/kaggle/input/large-number-tasks/ProgressivePrompts/BERT_codebase/run_prog_prompts.sh': Read-only file system
# ...

# %%
# %cd /kaggle/working/ProgressivePrompts/T5_codebase
import os
os.mkdir("load_checkpoint")
# %mv /kaggle/input/t5-1000-1/current_checkpoint.pt /kaggle/working/ProgressivePrompts/T5_codebase/load_checkpoint
# Out:
# /kaggle/working/ProgressivePrompts/T5_codebase
# mv: cannot remove '/kaggle/input/t5-1000-1/current_checkpoint.pt': Read-only file system

# %%
# %cd /kaggle/working/ProgressivePrompts
# %conda env create -f environment.yaml
# Out:
# /kaggle/working/ProgressivePrompts
# Retrieving notices: ...working... done
# ...
# WARNING conda.models.version:get_matcher(556): Using .* with relational operator is superfluous and deprecated and will be removed in a future version of conda. Your spec was 1.6.0.*, but conda is ignoring the .* and treating it as 1.6.0
# WARNING conda.models.version:get_matcher(556): Using .* with relational operator is superfluous and deprecated and will be removed in a future version of conda. Your spec was 1.7.1.*, but conda is ignoring the .* and treating it as 1.7.1
# WARNING conda.models.version:get_matcher(556): Using .* with relational operator is superfluous and deprecated and will be removed in a future version of conda. Your spec was 1.9.0.*, but conda is ignoring the .* and treating it as 1.9.0
# done
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 23.7.4
#   latest version: 23.10.0
#
# Please update conda by running
#
# ...

# %%
# %cd T5_codebase
import os
os.mkdir("results")
os.mkdir("save_checkpoint")
# Out:
# /kaggle/working/ProgressivePrompts/T5_codebase

# %%
# !source activate nlp && python train_t5_cl.py --task_list mnli cb wic copa qqp boolq rte imdb yelp_review_full amazon sst2 dbpedia_14 ag_news multirc yahoo_answers_topics \
--lr 0.3 --num_epochs 10 --freeze_weights 1 --prefix_len 10 --batch_size 4 \
--model_name t5-large --early_stopping 1 --select_k_per_class 1000 \
--save_name large_1000_T5_order_1 --save_dir results
# Out:
# Downloading: 100%|██████████████████████████| 1.18k/1.18k [00:00<00:00, 940kB/s]
# Downloading: 100%|█████████████████████████| 2.75G/2.75G [01:21<00:00, 36.3MB/s]
# Downloading: 100%|███████████████████████████| 773k/773k [00:00<00:00, 1.01MB/s]
# Freezing weights
# /opt/conda/envs/nlp/lib/python3.9/site-packages/transformers/optimization.py:306: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
# mnli
# Using custom data configuration LysandreJik--glue-mnli-train-aef4727e80ba5593
# ...
#
# ...
#
# ...
# Extracting data files: 100%|█████████████████████| 3/3 [00:00<00:00, 526.55it/s]
# ...

# %%
# !source activate nlp && python train_t5_cl.py --task_list mnli cb wic copa qqp boolq rte imdb yelp_review_full amazon sst2 dbpedia_14 ag_news multirc yahoo_answers_topics \
--lr 0.3 --num_epochs 10 --freeze_weights 1 --prefix_len 10 --batch_size 4 \
--model_name t5-large --early_stopping 1 --select_k_per_class 1000 \
--save_name large_1000_T5_order_1 --save_dir results --continue_train 1
# Out:
# Downloading: 100%|██████████████████████████| 1.18k/1.18k [00:00<00:00, 647kB/s]
# Downloading: 100%|█████████████████████████| 2.75G/2.75G [01:40<00:00, 29.4MB/s]
# Downloading: 100%|███████████████████████████| 773k/773k [00:00<00:00, 13.5MB/s]
# Freezing weights
# /opt/conda/envs/nlp/lib/python3.9/site-packages/transformers/optimization.py:306: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
# mnli
# Using custom data configuration LysandreJik--glue-mnli-train-aef4727e80ba5593
# ...
#
# ...
#
# ...
# Extracting data files: 100%|█████████████████████| 3/3 [00:00<00:00, 248.44it/s]
# ...

# %%
# !source activate nlp && python train_t5_cl.py --task_list mnli cb wic copa qqp boolq rte imdb yelp_review_full amazon sst2 dbpedia_14 ag_news multirc yahoo_answers_topics \
--lr 0.3 --num_epochs 10 --freeze_weights 1 --prefix_len 10 --batch_size 4 \
--model_name t5-large --early_stopping 1 --select_k_per_class 1000 \
--save_name large_1000_T5_order_1 --save_dir results --continue_train 1
# Out:
# Downloading: 100%|█████████████████████████| 1.18k/1.18k [00:00<00:00, 1.08MB/s]
# Downloading: 100%|█████████████████████████| 2.75G/2.75G [01:17<00:00, 38.3MB/s]
# Downloading: 100%|███████████████████████████| 773k/773k [00:00<00:00, 38.3MB/s]
# Freezing weights
# /opt/conda/envs/nlp/lib/python3.9/site-packages/transformers/optimization.py:306: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
# mnli
# Using custom data configuration LysandreJik--glue-mnli-train-aef4727e80ba5593
# ...
#
# ...
#
# ...
# Extracting data files: 100%|█████████████████████| 3/3 [00:00<00:00, 857.73it/s]
# ...

# %%
# !source activate nlp && python train_t5_cl.py --task_list mnli cb wic copa qqp boolq rte imdb yelp_review_full amazon sst2 dbpedia_14 ag_news multirc yahoo_answers_topics \
--lr 0.3 --num_epochs 10 --freeze_weights 1 --prefix_len 10 --batch_size 4 \
--model_name t5-large --early_stopping 1 --select_k_per_class 1000 \
--save_name large_1000_T5_order_1 --save_dir results --continue_train 1
# Out:
# Downloading: 100%|██████████████████████████| 1.18k/1.18k [00:00<00:00, 943kB/s]
# Downloading: 100%|█████████████████████████| 2.75G/2.75G [02:44<00:00, 18.0MB/s]
# Downloading: 100%|███████████████████████████| 773k/773k [00:00<00:00, 1.02MB/s]
# Freezing weights
# /opt/conda/envs/nlp/lib/python3.9/site-packages/transformers/optimization.py:306: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
# mnli
# Using custom data configuration LysandreJik--glue-mnli-train-aef4727e80ba5593
# ...
#
# ...
#
# ...
# Extracting data files: 100%|█████████████████████| 3/3 [00:00<00:00, 350.87it/s]
# ...

# %%
# !source activate nlp && python train_t5_cl.py --task_list mnli cb wic copa qqp boolq rte imdb yelp_review_full amazon sst2 dbpedia_14 ag_news multirc yahoo_answers_topics \
--lr 0.3 --num_epochs 10 --freeze_weights 1 --prefix_len 10 --batch_size 4 \
--model_name t5-large --early_stopping 1 --select_k_per_class 1000 \
--save_name large_1000_T5_order_1 --save_dir results --continue_train 1
# Out:
# Downloading: 100%|█████████████████████████| 1.18k/1.18k [00:00<00:00, 1.11MB/s]
# Downloading: 100%|█████████████████████████| 2.75G/2.75G [02:40<00:00, 18.3MB/s]
# Downloading: 100%|███████████████████████████| 773k/773k [00:00<00:00, 1.02MB/s]
# Freezing weights
# /opt/conda/envs/nlp/lib/python3.9/site-packages/transformers/optimization.py:306: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
# mnli
# Using custom data configuration LysandreJik--glue-mnli-train-aef4727e80ba5593
# ...
#
# ...
#
# ...
# Extracting data files: 100%|█████████████████████| 3/3 [00:00<00:00, 248.10it/s]
# ...

# %%
# %mv /kaggle/working/ProgressivePrompts/T5_codebase/save_checkpoint/current_checkpoint.pt /kaggle/working/
# %cd /kaggle/working
from IPython.display import FileLink
FileLink(r'current_checkpoint.pt')
# Out:
# /kaggle/working
# /kaggle/working/current_checkpoint.pt

# %%
import numpy as np
res = np.load('/kaggle/working/ProgressivePrompts/T5_codebase/results/large_1000_T5_order_1/results_dict.npy', allow_pickle=True)

# %%
res
# Out:
# array({'test': {'mnli': 0.876, 'cb': (0.9285714285714286, 0.8111111111111112), 'wic': 0.6865203761755486, 'copa': 0.5, 'qqp': 0.888, 'boolq': 0.818, 'rte': 0.8561151079136691, 'imdb': 0.948, 'yelp_review_full': 0.6392, 'amazon': 0.54, 'sst2': 0.9575, 'dbpedia_14': 0.9882857142857143, 'ag_news': 0.878, 'multirc': 0.774, 'yahoo_answers_topics': 0.7392}, 'mnli': [0.8706666666666667, 0.8746666666666667, 0.8733333333333333, 0.8733333333333333, 0.876, 0.8746666666666667, 0.88, 0.8746666666666667, 0.884, 0.8813333333333333], 'cb': [0.8347727980080921, 0.8347727980080921, 0.8347727980080921, 0.8347727980080921, 0.8347727980080921, 0.8347727980080921, 0.8854497354497355, 0.8854497354497355, 0.8854497354497355, 0.9178153717627402], 'wic': [0.5642633228840125, 0.6269592476489029, 0.6394984326018809, 0.6144200626959248, 0.5924764890282131, 0.6144200626959248, 0.6332288401253918, 0.6175548589341693, 0.64576802507837, 0.64576802507837], 'copa': [0.48, 0.52, 0.62, 0.44, 0.5, 0.5, 0.44, 0.6, 0.46, 0
# ...
