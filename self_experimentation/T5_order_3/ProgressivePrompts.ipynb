# %%
mv /kaggle/input/progressive-prompts/ProgressivePrompts /kaggle/working/
# Out:
# mv: cannot remove '/kaggle/input/progressive-prompts/ProgressivePrompts/environment.yaml': Read-only file system
# mv: cannot remove '/kaggle/input/progressive-prompts/ProgressivePrompts/LICENSE': Read-only file system
# mv: cannot remove '/kaggle/input/progressive-prompts/ProgressivePrompts/datasets/README.md': Read-only file system
# mv: cannot remove '/kaggle/input/progressive-prompts/ProgressivePrompts/datasets/src/data/ag/readme.txt': Read-only file system
# mv: cannot remove '/kaggle/input/progressive-prompts/ProgressivePrompts/datasets/src/data/ag/classes.txt': Read-only file system
# mv: cannot remove '/kaggle/input/progressive-prompts/ProgressivePrompts/datasets/src/data/ag/train.csv': Read-only file system
# mv: cannot remove '/kaggle/input/progressive-prompts/ProgressivePrompts/datasets/src/data/ag/test.csv': Read-only file system
# mv: cannot remove '/kaggle/input/progressive-prompts/ProgressivePrompts/datasets/src/data/dbpedia/readme.txt': Read-only file system
# ...

# %%
# %cd /kaggle/working/ProgressivePrompts/T5_codebase
import os
os.mkdir("load_checkpoint")
# %mv /kaggle/input/t5-order-3/current_checkpoint.pt /kaggle/working/ProgressivePrompts/T5_codebase/load_checkpoint
# Out:
# /kaggle/working/ProgressivePrompts/T5_codebase
# mv: cannot remove '/kaggle/input/t5-order-3/current_checkpoint.pt': Read-only file system

# %%
# %cd /kaggle/working/ProgressivePrompts
# %conda env create -f environment.yaml
# Out:
# /kaggle/working/ProgressivePrompts
# Retrieving notices: ...working... done
# ...
# WARNING conda.models.version:get_matcher(556): Using .* with relational operator is superfluous and deprecated and will be removed in a future version of conda. Your spec was 1.7.1.*, but conda is ignoring the .* and treating it as 1.7.1
# WARNING conda.models.version:get_matcher(556): Using .* with relational operator is superfluous and deprecated and will be removed in a future version of conda. Your spec was 1.9.0.*, but conda is ignoring the .* and treating it as 1.9.0
# WARNING conda.models.version:get_matcher(556): Using .* with relational operator is superfluous and deprecated and will be removed in a future version of conda. Your spec was 1.6.0.*, but conda is ignoring the .* and treating it as 1.6.0
# done
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 23.7.4
#   latest version: 23.10.0
#
# Please update conda by running
#
# ...

# %%
# %cd T5_codebase
import os
os.mkdir("results")
os.mkdir("save_checkpoint")
# Out:
# /kaggle/working/ProgressivePrompts/T5_codebase

# %%
# !source activate nlp && python train_t5_cl.py --task_list yahoo_answers_topics amazon ag_news dbpedia_14 \
--lr 0.3 --num_epochs 10 --freeze_weights 1 --prefix_len 50 --batch_size 4 \
--model_name t5-large --early_stopping 1 \
--save_name T5_order_3 --save_dir results
# Out:
# Downloading: 100%|█████████████████████████| 1.18k/1.18k [00:00<00:00, 1.29MB/s]
# Downloading: 100%|█████████████████████████| 2.75G/2.75G [00:51<00:00, 57.6MB/s]
# Downloading: 100%|███████████████████████████| 773k/773k [00:00<00:00, 2.44MB/s]
# Freezing weights
# /opt/conda/envs/nlp/lib/python3.9/site-packages/transformers/optimization.py:306: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
# yahoo_answers_topics
# ...
# Dataset yahoo_answers_topics downloaded and prepared to /root/.cache/huggingface/datasets/yahoo_answers_topics/yahoo_answers_topics/1.0.0/0edb353eefe79d9245d7bd7cac5ae6af19530439da520d6dde1c206ee38f4439. Subsequent calls will reuse this data.
# ...

# %%
# !source activate nlp && python train_t5_cl.py --task_list yahoo_answers_topics amazon ag_news dbpedia_14 \
--lr 0.3 --num_epochs 10 --freeze_weights 1 --prefix_len 50 --batch_size 4 \
--model_name t5-large --early_stopping 1 \
--save_name T5_order_3 --save_dir results --continue_train 1
# Out:
# Downloading: 100%|██████████████████████████| 1.18k/1.18k [00:00<00:00, 933kB/s]
# Downloading: 100%|█████████████████████████| 2.75G/2.75G [00:58<00:00, 50.4MB/s]
# Downloading: 100%|███████████████████████████| 773k/773k [00:00<00:00, 11.4MB/s]
# Freezing weights
# /opt/conda/envs/nlp/lib/python3.9/site-packages/transformers/optimization.py:306: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
# yahoo_answers_topics
# ...
# Dataset yahoo_answers_topics downloaded and prepared to /root/.cache/huggingface/datasets/yahoo_answers_topics/yahoo_answers_topics/1.0.0/0edb353eefe79d9245d7bd7cac5ae6af19530439da520d6dde1c206ee38f4439. Subsequent calls will reuse this data.
# ...

# %%
# !source activate nlp && python train_t5_cl.py --task_list yahoo_answers_topics amazon ag_news dbpedia_14 \
--lr 0.3 --num_epochs 10 --freeze_weights 1 --prefix_len 50 --batch_size 4 \
--model_name t5-large --early_stopping 1 \
--save_name T5_order_3 --save_dir results --continue_train 1
# Out:
# Downloading: 100%|██████████████████████████| 1.18k/1.18k [00:00<00:00, 970kB/s]
# Downloading: 100%|█████████████████████████| 2.75G/2.75G [00:51<00:00, 57.6MB/s]
# Downloading: 100%|███████████████████████████| 773k/773k [00:00<00:00, 2.43MB/s]
# Freezing weights
# /opt/conda/envs/nlp/lib/python3.9/site-packages/transformers/optimization.py:306: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
# yahoo_answers_topics
# ...
# Dataset yahoo_answers_topics downloaded and prepared to /root/.cache/huggingface/datasets/yahoo_answers_topics/yahoo_answers_topics/1.0.0/0edb353eefe79d9245d7bd7cac5ae6af19530439da520d6dde1c206ee38f4439. Subsequent calls will reuse this data.
# ...

# %%
# !source activate nlp && python train_t5_cl.py --task_list yahoo_answers_topics amazon ag_news dbpedia_14 \
--lr 0.3 --num_epochs 10 --freeze_weights 1 --prefix_len 50 --batch_size 4 \
--model_name t5-large --early_stopping 1 \
--save_name T5_order_3 --save_dir results --continue_train 1
# Out:
# Downloading: 100%|█████████████████████████| 1.18k/1.18k [00:00<00:00, 1.11MB/s]
# Downloading: 100%|█████████████████████████| 2.75G/2.75G [00:52<00:00, 55.9MB/s]
# Downloading: 100%|███████████████████████████| 773k/773k [00:00<00:00, 4.36MB/s]
# Freezing weights
# /opt/conda/envs/nlp/lib/python3.9/site-packages/transformers/optimization.py:306: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
# yahoo_answers_topics
# ...
# Dataset yahoo_answers_topics downloaded and prepared to /root/.cache/huggingface/datasets/yahoo_answers_topics/yahoo_answers_topics/1.0.0/0edb353eefe79d9245d7bd7cac5ae6af19530439da520d6dde1c206ee38f4439. Subsequent calls will reuse this data.
# ...

# %%
# !source activate nlp && python train_t5_cl.py --task_list yahoo_answers_topics amazon ag_news dbpedia_14 \
--lr 0.3 --num_epochs 10 --freeze_weights 1 --prefix_len 50 --batch_size 4 \
--model_name t5-large --early_stopping 1 \
--save_name T5_order_3 --save_dir results --continue_train 1
# Out:
# Downloading: 100%|██████████████████████████| 1.18k/1.18k [00:00<00:00, 943kB/s]
# Downloading: 100%|█████████████████████████| 2.75G/2.75G [01:03<00:00, 46.5MB/s]
# Downloading: 100%|███████████████████████████| 773k/773k [00:00<00:00, 38.2MB/s]
# Freezing weights
# /opt/conda/envs/nlp/lib/python3.9/site-packages/transformers/optimization.py:306: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
# yahoo_answers_topics
# ...
# Dataset yahoo_answers_topics downloaded and prepared to /root/.cache/huggingface/datasets/yahoo_answers_topics/yahoo_answers_topics/1.0.0/0edb353eefe79d9245d7bd7cac5ae6af19530439da520d6dde1c206ee38f4439. Subsequent calls will reuse this data.
# ...

# %%
# !source activate nlp && python train_t5_cl.py --task_list yahoo_answers_topics amazon ag_news dbpedia_14 \
--lr 0.3 --num_epochs 10 --freeze_weights 1 --prefix_len 50 --batch_size 4 \
--model_name t5-large --early_stopping 1 \
--save_name T5_order_3 --save_dir results --continue_train 1
# Out:
# Downloading: 100%|█████████████████████████| 1.18k/1.18k [00:00<00:00, 1.13MB/s]
# Downloading: 100%|█████████████████████████| 2.75G/2.75G [00:50<00:00, 58.2MB/s]
# Downloading: 100%|███████████████████████████| 773k/773k [00:00<00:00, 6.24MB/s]
# Freezing weights
# /opt/conda/envs/nlp/lib/python3.9/site-packages/transformers/optimization.py:306: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
# yahoo_answers_topics
# ...
# Dataset yahoo_answers_topics downloaded and prepared to /root/.cache/huggingface/datasets/yahoo_answers_topics/yahoo_answers_topics/1.0.0/0edb353eefe79d9245d7bd7cac5ae6af19530439da520d6dde1c206ee38f4439. Subsequent calls will reuse this data.
# ...

# %%
# !source activate nlp && python train_t5_cl.py --task_list yahoo_answers_topics amazon ag_news dbpedia_14 \
--lr 0.3 --num_epochs 10 --freeze_weights 1 --prefix_len 50 --batch_size 4 \
--model_name t5-large --early_stopping 1 \
--save_name T5_order_3 --save_dir results --continue_train 1
# Out:
# Downloading: 100%|█████████████████████████| 1.18k/1.18k [00:00<00:00, 1.44MB/s]
# Downloading: 100%|█████████████████████████| 2.75G/2.75G [00:51<00:00, 57.6MB/s]
# Downloading: 100%|███████████████████████████| 773k/773k [00:00<00:00, 13.3MB/s]
# Freezing weights
# /opt/conda/envs/nlp/lib/python3.9/site-packages/transformers/optimization.py:306: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
# yahoo_answers_topics
# ...
# Dataset yahoo_answers_topics downloaded and prepared to /root/.cache/huggingface/datasets/yahoo_answers_topics/yahoo_answers_topics/1.0.0/0edb353eefe79d9245d7bd7cac5ae6af19530439da520d6dde1c206ee38f4439. Subsequent calls will reuse this data.
# ...

# %%
# %mv /kaggle/working/ProgressivePrompts/T5_codebase/save_checkpoint/current_checkpoint.pt /kaggle/working/
# %cd /kaggle/working
from IPython.display import FileLink
FileLink(r'current_checkpoint.pt')
# Out:
# /kaggle/working
# /kaggle/working/current_checkpoint.pt

# %%
import numpy as np
res = np.load('/kaggle/working/ProgressivePrompts/T5_codebase/results/T5_order_3/results_dict.npy', allow_pickle=True)

# %%
res
# Out:
# array({'test': {'yahoo_answers_topics': 0.7756, 'amazon': 0.632, 'ag_news': 0.926, 'dbpedia_14': 0.988}, 'yahoo_answers_topics': [0.74, 0.7532, 0.7552, 0.7724, 0.768, 0.7656, 0.7684, 0.7788, 0.7752, 0.7772], 'amazon': [0.5416, 0.5688, 0.6024, 0.6032, 0.624, 0.6344, 0.644, 0.636, 0.648, 0.6488], 'ag_news': [0.895, 0.912, 0.919, 0.908, 0.921, 0.918, 0.921, 0.922, 0.925, 0.93], 'dbpedia_14': [0.9771428571428571, 0.9854285714285714, 0.9874285714285714, 0.9865714285714285, 0.9891428571428571, 0.9734285714285714, 0.9857142857142858, 0.9871428571428571, 0.9865714285714285, 0.9891428571428571]},
#       dtype=object)

# %%
# !source activate nlp && python train_t5_cl.py --task_list yahoo_answers_topics amazon ag_news dbpedia_14 \
--lr 0.3 --num_epochs 10 --freeze_weights 1 --prefix_len 50 --batch_size 4 \
--model_name t5-large --early_stopping 1 \
--save_name T5_order_3 --save_dir results --continue_train 1 --test_eval_after_every_task 1
# Out:
# Downloading: 100%|██████████████████████████| 1.18k/1.18k [00:00<00:00, 995kB/s]
# Downloading: 100%|█████████████████████████| 2.75G/2.75G [00:52<00:00, 56.3MB/s]
# Downloading: 100%|███████████████████████████| 773k/773k [00:00<00:00, 28.1MB/s]
# Freezing weights
# /opt/conda/envs/nlp/lib/python3.9/site-packages/transformers/optimization.py:306: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
# yahoo_answers_topics
# ...
# Dataset yahoo_answers_topics downloaded and prepared to /root/.cache/huggingface/datasets/yahoo_answers_topics/yahoo_answers_topics/1.0.0/0edb353eefe79d9245d7bd7cac5ae6af19530439da520d6dde1c206ee38f4439. Subsequent calls will reuse this data.
# ...

# %%
import numpy as np
res = np.load('/kaggle/working/ProgressivePrompts/T5_codebase/results/T5_order_3/results_dict.npy', allow_pickle=True)

# %%
res
# Out:
# array({'test': {'yahoo_answers_topics': 0.7756, 'amazon': 0.632, 'ag_news': 0.926, 3: {'yahoo_answers_topics': 0.0188, 'amazon': 0.0, 'ag_news': 0.038, 'dbpedia_14': 0.988}}, 'yahoo_answers_topics': [0.74, 0.7532, 0.7552, 0.7724, 0.768, 0.7656, 0.7684, 0.7788, 0.7752, 0.7772], 'amazon': [0.5416, 0.5688, 0.6024, 0.6032, 0.624, 0.6344, 0.644, 0.636, 0.648, 0.6488], 'ag_news': [0.895, 0.912, 0.919, 0.908, 0.921, 0.918, 0.921, 0.922, 0.925, 0.93], 'dbpedia_14': [0.9771428571428571, 0.9854285714285714, 0.9874285714285714, 0.9865714285714285, 0.9891428571428571, 0.9734285714285714, 0.9857142857142858, 0.9871428571428571, 0.988, 0.9888571428571429]},
#       dtype=object)
