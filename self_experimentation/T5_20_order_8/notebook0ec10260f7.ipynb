# %%
mv /kaggle/input/large-number-tasks/ProgressivePrompts /kaggle/working/
# Out:
# mv: cannot remove '/kaggle/input/large-number-tasks/ProgressivePrompts/environment.yaml': Read-only file system
# mv: cannot remove '/kaggle/input/large-number-tasks/ProgressivePrompts/LICENSE': Read-only file system
# mv: cannot remove '/kaggle/input/large-number-tasks/ProgressivePrompts/datasets/README.md': Read-only file system
# mv: cannot remove '/kaggle/input/large-number-tasks/ProgressivePrompts/datasets/src/data/amazon/train.csv': Read-only file system
# mv: cannot remove '/kaggle/input/large-number-tasks/ProgressivePrompts/datasets/src/data/amazon/test.csv': Read-only file system
# mv: cannot remove '/kaggle/input/large-number-tasks/ProgressivePrompts/BERT_codebase/train_soft_prompt.py': Read-only file system
# mv: cannot remove '/kaggle/input/large-number-tasks/ProgressivePrompts/BERT_codebase/train_cl2.py': Read-only file system
# mv: cannot remove '/kaggle/input/large-number-tasks/ProgressivePrompts/BERT_codebase/run_prog_prompts.sh': Read-only file system
# ...

# %%
# %cd /kaggle/working/ProgressivePrompts/T5_codebase
import os
os.mkdir("load_checkpoint")
# %mv /kaggle/input/large20-1/current_checkpoint.pt /kaggle/working/ProgressivePrompts/T5_codebase/load_checkpoint
# Out:
# /kaggle/working/ProgressivePrompts/T5_codebase
# mv: cannot remove '/kaggle/input/large20-1/current_checkpoint.pt': Read-only file system

# %%
# %cd /kaggle/working/ProgressivePrompts
# %conda env create -f environment.yaml
# Out:
# /kaggle/working/ProgressivePrompts
# Retrieving notices: ...working... done
# ...
# WARNING conda.models.version:get_matcher(556): Using .* with relational operator is superfluous and deprecated and will be removed in a future version of conda. Your spec was 1.8.0.*, but conda is ignoring the .* and treating it as 1.8.0
# WARNING conda.models.version:get_matcher(556): Using .* with relational operator is superfluous and deprecated and will be removed in a future version of conda. Your spec was 1.7.1.*, but conda is ignoring the .* and treating it as 1.7.1
# WARNING conda.models.version:get_matcher(556): Using .* with relational operator is superfluous and deprecated and will be removed in a future version of conda. Your spec was 1.9.0.*, but conda is ignoring the .* and treating it as 1.9.0
# done
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 23.7.4
#   latest version: 23.10.0
#
# Please update conda by running
#
# ...

# %%
# %cd T5_codebase
import os
os.mkdir("results")
os.mkdir("save_checkpoint")
# Out:
# /kaggle/working/ProgressivePrompts/T5_codebase

# %%
# !source activate nlp && python train_t5_cl.py --task_list mnli cb wic copa qqp boolq rte imdb yelp_review_full amazon sst2 dbpedia_14 ag_news multirc yahoo_answers_topics \
--lr 0.3 --num_epochs 300 --freeze_weights 1 --prefix_len 10 --batch_size 4 \
--model_name t5-large --early_stopping 1 --select_k_per_class 20 \
--save_name large_T5_order_1 --save_dir results
# Out:
# Downloading: 100%|█████████████████████████| 1.18k/1.18k [00:00<00:00, 1.04MB/s]
# Downloading: 100%|█████████████████████████| 2.75G/2.75G [02:11<00:00, 22.4MB/s]
# Downloading: 100%|███████████████████████████| 773k/773k [00:00<00:00, 2.38MB/s]
# Freezing weights
# /opt/conda/envs/nlp/lib/python3.9/site-packages/transformers/optimization.py:306: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
# mnli
# Using custom data configuration LysandreJik--glue-mnli-train-aef4727e80ba5593
# ...
#
# ...
#
# ...
# Extracting data files: 100%|█████████████████████| 3/3 [00:00<00:00, 296.62it/s]
# ...

# %%
# !source activate nlp && python train_t5_cl.py --task_list mnli cb wic copa qqp boolq rte imdb yelp_review_full amazon sst2 dbpedia_14 ag_news multirc yahoo_answers_topics \
--lr 0.3 --num_epochs 300 --freeze_weights 1 --prefix_len 10 --batch_size 4 \
--model_name t5-large --early_stopping 1 --select_k_per_class 20 \
--save_name large_T5_order_1 --save_dir results --continue_train 1
# Out:
# Downloading: 100%|█████████████████████████| 1.18k/1.18k [00:00<00:00, 1.08MB/s]
# Downloading: 100%|█████████████████████████| 2.75G/2.75G [00:51<00:00, 57.5MB/s]
# Downloading: 100%|███████████████████████████| 773k/773k [00:00<00:00, 2.40MB/s]
# Freezing weights
# /opt/conda/envs/nlp/lib/python3.9/site-packages/transformers/optimization.py:306: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
# mnli
# Using custom data configuration LysandreJik--glue-mnli-train-aef4727e80ba5593
# ...
#
# ...
#
# ...
# Extracting data files: 100%|█████████████████████| 3/3 [00:00<00:00, 224.90it/s]
# ...

# %%
# !source activate nlp && python train_t5_cl.py --task_list mnli cb wic copa qqp boolq rte imdb yelp_review_full amazon sst2 dbpedia_14 ag_news multirc yahoo_answers_topics \
--lr 0.3 --num_epochs 300 --freeze_weights 1 --prefix_len 10 --batch_size 4 \
--model_name t5-large --early_stopping 1 --select_k_per_class 20 \
--save_name large_T5_order_1 --save_dir results --continue_train 1
# Out:
# Downloading: 100%|█████████████████████████| 1.18k/1.18k [00:00<00:00, 1.01MB/s]
# Downloading: 100%|█████████████████████████| 2.75G/2.75G [00:50<00:00, 58.0MB/s]
# Downloading: 100%|███████████████████████████| 773k/773k [00:00<00:00, 11.9MB/s]
# Freezing weights
# /opt/conda/envs/nlp/lib/python3.9/site-packages/transformers/optimization.py:306: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
# mnli
# Using custom data configuration LysandreJik--glue-mnli-train-aef4727e80ba5593
# ...
#
# ...
#
# ...
# Extracting data files: 100%|█████████████████████| 3/3 [00:00<00:00, 220.94it/s]
# ...

# %%
# !source activate nlp && python train_t5_cl.py --task_list mnli cb wic copa qqp boolq rte imdb yelp_review_full amazon sst2 dbpedia_14 ag_news multirc yahoo_answers_topics \
--lr 0.3 --num_epochs 300 --freeze_weights 1 --prefix_len 10 --batch_size 4 \
--model_name t5-large --early_stopping 1 --select_k_per_class 20 \
--save_name large_T5_order_1 --save_dir results --continue_train 1
# Out:
# Downloading: 100%|██████████████████████████| 1.18k/1.18k [00:00<00:00, 985kB/s]
# Downloading: 100%|█████████████████████████| 2.75G/2.75G [01:10<00:00, 41.9MB/s]
# Downloading: 100%|███████████████████████████| 773k/773k [00:00<00:00, 1.98MB/s]
# Freezing weights
# /opt/conda/envs/nlp/lib/python3.9/site-packages/transformers/optimization.py:306: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
# mnli
# Using custom data configuration LysandreJik--glue-mnli-train-aef4727e80ba5593
# ...
#
# ...
#
# ...
# Extracting data files: 100%|█████████████████████| 3/3 [00:00<00:00, 271.84it/s]
# ...

# %%
# !source activate nlp && python train_t5_cl.py --task_list mnli cb wic copa qqp boolq rte imdb yelp_review_full amazon sst2 dbpedia_14 ag_news multirc yahoo_answers_topics \
--lr 0.3 --num_epochs 300 --freeze_weights 1 --prefix_len 10 --batch_size 4 \
--model_name t5-large --early_stopping 1 --select_k_per_class 20 \
--save_name large_T5_order_1 --save_dir results --continue_train 1
# Out:
# Downloading: 100%|█████████████████████████| 1.18k/1.18k [00:00<00:00, 1.13MB/s]
# Downloading: 100%|█████████████████████████| 2.75G/2.75G [00:50<00:00, 58.6MB/s]
# Downloading: 100%|███████████████████████████| 773k/773k [00:00<00:00, 2.39MB/s]
# Freezing weights
# /opt/conda/envs/nlp/lib/python3.9/site-packages/transformers/optimization.py:306: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
# mnli
# Using custom data configuration LysandreJik--glue-mnli-train-aef4727e80ba5593
# ...
#
# ...
#
# ...
# Extracting data files: 100%|█████████████████████| 3/3 [00:00<00:00, 186.71it/s]
# ...

# %%
# !source activate nlp && python train_t5_cl.py --task_list mnli cb wic copa qqp boolq rte imdb yelp_review_full amazon sst2 dbpedia_14 ag_news multirc yahoo_answers_topics \
--lr 0.3 --num_epochs 300 --freeze_weights 1 --prefix_len 10 --batch_size 4 \
--model_name t5-large --early_stopping 1 --select_k_per_class 20 \
--save_name large_T5_order_1 --save_dir results --continue_train 1
# Out:
# Downloading: 100%|██████████████████████████| 1.18k/1.18k [00:00<00:00, 621kB/s]
# Downloading: 100%|█████████████████████████| 2.75G/2.75G [01:15<00:00, 39.3MB/s]
# Downloading: 100%|███████████████████████████| 773k/773k [00:00<00:00, 1.95MB/s]
# Freezing weights
# /opt/conda/envs/nlp/lib/python3.9/site-packages/transformers/optimization.py:306: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
# mnli
# Using custom data configuration LysandreJik--glue-mnli-train-aef4727e80ba5593
# ...
#
# ...
#
# ...
# Extracting data files: 100%|█████████████████████| 3/3 [00:00<00:00, 837.80it/s]
# ...

# %%
# %mv /kaggle/working/ProgressivePrompts/T5_codebase/save_checkpoint/current_checkpoint.pt /kaggle/working/
# %cd /kaggle/working
from IPython.display import FileLink
FileLink(r'current_checkpoint.pt')
# Out:
# /kaggle/working
# /kaggle/working/current_checkpoint.pt

# %%
import numpy as np
res = np.load('/kaggle/working/results_dict.npy', allow_pickle=True)

# %%
res
# Out:
# array({'test': {'mnli': 0.8773333333333333, 'cb': (0.9642857142857143, 0.9218390804597701), 'wic': 0.6363636363636364, 'copa': 0.48, 'qqp': 0.922, 'boolq': 0.818, 'rte': 0.8057553956834532, 'imdb': 0.932, 'yelp_review_full': 0.5648, 'amazon': 0.5112, 'sst2': 0.9375, 'dbpedia_14': 0.9797142857142858, 'ag_news': 0.834, 'multirc': 0.718, 'yahoo_answers_topics': 0.6956}, 'mnli': [0.8346666666666667, 0.832, 0.84, 0.8546666666666667, 0.8506666666666667, 0.8573333333333333, 0.868, 0.8733333333333333, 0.884, 0.888, 0.8813333333333333, 0.8826666666666667, 0.884, 0.8746666666666667, 0.88, 0.8866666666666667, 0.8746666666666667, 0.8853333333333333, 0.8786666666666667, 0.8706666666666667, 0.872, 0.8746666666666667, 0.884, 0.8733333333333333, 0.884, 0.8653333333333333, 0.8786666666666667, 0.8853333333333333, 0.872, 0.8826666666666667], 'cb': [0.8228595478595478, 0.9178153717627402, 0.8854497354497355, 0.9675770308123249, 0.9053571428571429, 0.8602357609710551, 0.9113445378151261, 0.96757703081232
# ...
