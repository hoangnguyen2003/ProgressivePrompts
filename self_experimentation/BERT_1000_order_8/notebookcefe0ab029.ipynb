# %%
mv /kaggle/input/large-number-tasks/ProgressivePrompts /kaggle/working/
# Out:
# mv: cannot remove '/kaggle/input/large-number-tasks/ProgressivePrompts/environment.yaml': Read-only file system
# mv: cannot remove '/kaggle/input/large-number-tasks/ProgressivePrompts/LICENSE': Read-only file system
# mv: cannot remove '/kaggle/input/large-number-tasks/ProgressivePrompts/datasets/README.md': Read-only file system
# mv: cannot remove '/kaggle/input/large-number-tasks/ProgressivePrompts/datasets/src/data/amazon/train.csv': Read-only file system
# mv: cannot remove '/kaggle/input/large-number-tasks/ProgressivePrompts/datasets/src/data/amazon/test.csv': Read-only file system
# mv: cannot remove '/kaggle/input/large-number-tasks/ProgressivePrompts/BERT_codebase/train_soft_prompt.py': Read-only file system
# mv: cannot remove '/kaggle/input/large-number-tasks/ProgressivePrompts/BERT_codebase/train_cl2.py': Read-only file system
# mv: cannot remove '/kaggle/input/large-number-tasks/ProgressivePrompts/BERT_codebase/run_prog_prompts.sh': Read-only file system
# ...

# %%
# %cd /kaggle/working/ProgressivePrompts/BERT_codebase
import os
os.mkdir("load_checkpoint")
# %mv /kaggle/input/bert-1000-1/current_checkpoint.pt /kaggle/working/ProgressivePrompts/BERT_codebase/load_checkpoint
# Out:
# /kaggle/working/ProgressivePrompts/BERT_codebase
# mv: cannot remove '/kaggle/input/bert-1000-1/current_checkpoint.pt': Read-only file system

# %%
# %cd /kaggle/working/ProgressivePrompts
# %conda env create -f environment.yaml
# Out:
# /kaggle/working/ProgressivePrompts
# Retrieving notices: ...working... done
# ...
# WARNING conda.models.version:get_matcher(556): Using .* with relational operator is superfluous and deprecated and will be removed in a future version of conda. Your spec was 1.9.0.*, but conda is ignoring the .* and treating it as 1.9.0
# WARNING conda.models.version:get_matcher(556): Using .* with relational operator is superfluous and deprecated and will be removed in a future version of conda. Your spec was 1.6.0.*, but conda is ignoring the .* and treating it as 1.6.0
# WARNING conda.models.version:get_matcher(556): Using .* with relational operator is superfluous and deprecated and will be removed in a future version of conda. Your spec was 1.7.1.*, but conda is ignoring the .* and treating it as 1.7.1
# done
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 23.7.4
#   latest version: 23.10.0
#
# Please update conda by running
#
# ...

# %%
# %cd BERT_codebase
import os
os.mkdir("results")
os.mkdir("save_checkpoint")
# Out:
# /kaggle/working/ProgressivePrompts/BERT_codebase

# %%
# !source activate nlp && python train_cl2.py --task_list mnli cb wic copa qqp boolq rte imdb yelp_review_full amazon sst2 dbpedia_14 ag_news multirc yahoo_answers_topics \
--prefix_MLP residual_MLP2 --lr 1e-4 --num_epochs 40 --freeze_weights 1 --prefix_len 20 \
--early_stopping 1 --seq_len 180 --prompt_tuning 1 --select_k_per_class 1000 \
--save_name large_1000_BERT_order_1 --save_dir results
# Out:
# Max repeats =  0
# Using MLP reparametrization with bottleneck =  800
# Downloading: 100%|███████████████████████████| 28.0/28.0 [00:00<00:00, 28.7kB/s]
# Downloading: 100%|██████████████████████████████| 570/570 [00:00<00:00, 449kB/s]
# Downloading: 100%|███████████████████████████| 226k/226k [00:00<00:00, 14.5MB/s]
# Downloading: 100%|███████████████████████████| 455k/455k [00:00<00:00, 1.18MB/s]
# Downloading: 100%|███████████████████████████| 420M/420M [00:09<00:00, 47.3MB/s]
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertAdapterModel: ['cls.predictions.transform.dense.weight', 'cls.predictions.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.decoder.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.transform.dense.bias', 'cls.seq_relationship.bias', 'cls.seq_relationship.weight']
# ...

# %%
# !source activate nlp && python train_cl2.py --task_list mnli cb wic copa qqp boolq rte imdb yelp_review_full amazon sst2 dbpedia_14 ag_news multirc yahoo_answers_topics \
--prefix_MLP residual_MLP2 --lr 1e-4 --num_epochs 40 --freeze_weights 1 --prefix_len 20 \
--early_stopping 1 --seq_len 180 --prompt_tuning 1 --select_k_per_class 1000 \
--save_name large_1000_BERT_order_1 --save_dir results --continue_train 1
# Out:
# Max repeats =  0
# Using MLP reparametrization with bottleneck =  800
# Downloading: 100%|███████████████████████████| 28.0/28.0 [00:00<00:00, 17.6kB/s]
# Downloading: 100%|██████████████████████████████| 570/570 [00:00<00:00, 484kB/s]
# Downloading: 100%|███████████████████████████| 226k/226k [00:00<00:00, 1.16MB/s]
# Downloading: 100%|████████████████████████████| 455k/455k [00:00<00:00, 817kB/s]
# Downloading: 100%|███████████████████████████| 420M/420M [00:07<00:00, 56.5MB/s]
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertAdapterModel: ['cls.seq_relationship.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.transform.dense.bias', 'cls.predictions.bias', 'cls.predictions.decoder.weight', 'cls.predictions.transform.dense.weight', 'cls.seq_relationship.bias', 'cls.predictions.transform.LayerNorm.weight']
# ...

# %%
# !source activate nlp && python train_cl2.py --task_list mnli cb wic copa qqp boolq rte imdb yelp_review_full amazon sst2 dbpedia_14 ag_news multirc yahoo_answers_topics \
--prefix_MLP residual_MLP2 --lr 1e-4 --num_epochs 40 --freeze_weights 1 --prefix_len 20 \
--early_stopping 1 --seq_len 180 --prompt_tuning 1 --select_k_per_class 1000 \
--save_name large_1000_BERT_order_1 --save_dir results --continue_train 1
# Out:
# Max repeats =  0
# Using MLP reparametrization with bottleneck =  800
# Downloading: 100%|███████████████████████████| 28.0/28.0 [00:00<00:00, 16.8kB/s]
# Downloading: 100%|██████████████████████████████| 570/570 [00:00<00:00, 389kB/s]
# Downloading: 100%|███████████████████████████| 226k/226k [00:00<00:00, 6.59MB/s]
# Downloading: 100%|███████████████████████████| 455k/455k [00:00<00:00, 6.96MB/s]
# Downloading: 100%|███████████████████████████| 420M/420M [00:07<00:00, 58.6MB/s]
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertAdapterModel: ['cls.predictions.transform.dense.bias', 'cls.predictions.transform.LayerNorm.bias', 'cls.seq_relationship.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.decoder.weight', 'cls.predictions.transform.dense.weight', 'cls.predictions.bias', 'cls.seq_relationship.weight']
# ...

# %%
# !source activate nlp && python train_cl2.py --task_list mnli cb wic copa qqp boolq rte imdb yelp_review_full amazon sst2 dbpedia_14 ag_news multirc yahoo_answers_topics \
--prefix_MLP residual_MLP2 --lr 1e-4 --num_epochs 40 --freeze_weights 1 --prefix_len 20 \
--early_stopping 1 --seq_len 180 --prompt_tuning 1 --select_k_per_class 1000 \
--save_name large_1000_BERT_order_1 --save_dir results --continue_train 1
# Out:
# Max repeats =  0
# Using MLP reparametrization with bottleneck =  800
# Downloading: 100%|███████████████████████████| 28.0/28.0 [00:00<00:00, 31.3kB/s]
# Downloading: 100%|██████████████████████████████| 570/570 [00:00<00:00, 464kB/s]
# Downloading: 100%|███████████████████████████| 226k/226k [00:00<00:00, 6.11MB/s]
# Downloading: 100%|███████████████████████████| 455k/455k [00:00<00:00, 9.47MB/s]
# Downloading: 100%|███████████████████████████| 420M/420M [00:07<00:00, 56.7MB/s]
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertAdapterModel: ['cls.seq_relationship.bias', 'cls.seq_relationship.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.bias', 'cls.predictions.transform.dense.bias', 'cls.predictions.transform.dense.weight', 'cls.predictions.decoder.weight']
# ...

# %%
# %mv /kaggle/working/ProgressivePrompts/BERT_codebase/save_checkpoint/current_checkpoint.pt /kaggle/working/
# %cd /kaggle/working
from IPython.display import FileLink
FileLink(r'current_checkpoint.pt')
# Out:
# /kaggle/working
# /kaggle/working/current_checkpoint.pt

# %%
import numpy as np
res = np.load('/kaggle/working/ProgressivePrompts/BERT_codebase/results/large_1000_BERT_order_1/results_dict.npy', allow_pickle=True)

# %%
res
# Out:
# array({0: {'mnli': [0.35555555555555557, 0.44222222222222224, 0.46444444444444444, 0.43333333333333335, 0.4777777777777778, 0.5111111111111111, 0.5222222222222223, 0.5311111111111111, 0.5244444444444445, 0.54, 0.5355555555555556, 0.5133333333333333, 0.5644444444444444, 0.56, 0.5622222222222222, 0.5644444444444444, 0.56, 0.58, 0.5977777777777777, 0.5688888888888889, 0.5866666666666667, 0.6022222222222222, 0.5955555555555555, 0.6066666666666667, 0.5622222222222222, 0.5955555555555555, 0.5933333333333334, 0.5955555555555555, 0.5866666666666667, 0.5911111111111111, 0.5933333333333334, 0.6066666666666667, 0.6155555555555555, 0.5844444444444444, 0.5844444444444444, 0.6155555555555555, 0.6155555555555555, 0.6222222222222222, 0.6177777777777778, 0.6133333333333333], 'cb': [], 'wic': [], 'copa': [], 'qqp': [], 'boolq': [], 'rte': [], 'imdb': [], 'yelp_review_full': [], 'amazon': [], 'sst2': [], 'dbpedia_14': [], 'ag_news': [], 'multirc': [], 'yahoo_answers_topics': []}, 'test': {'mnli': [0.59
# ...
